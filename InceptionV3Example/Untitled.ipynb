# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import tensorflow as tf
import numpy as np
image_raw = tf.gfile.FastGFile('flower_photos\\daisy\\5547758_eea9edfd54_n.jpg','rb').read()  #bytes，相对路径
img = tf.image.decode_jpeg(image_raw)  #Tensor
with tf.Session() as sess:
    print(type(image_raw)) # bytes
    print(type(img)) # Tensor
    print(type(img.eval())) # ndarray
    print(img.eval().shape)#(240,320,3)
    print(img.eval().dtype)#uint8
    nd = img.eval()
    img2 = tf.image.encode_jpeg(nd)
    plt.figure(1)
    plt.imshow(img.eval()) 
    plt.show()
# Out:
# <class 'bytes'>
# <class 'tensorflow.python.framework.ops.Tensor'>
# <class 'numpy.ndarray'>
# (232, 320, 3)
# uint8
# [[[ 94 131  53]
#   [ 87 125  48]
#   [ 83 121  48]
#   ...
#   [ 29  63  13]
#   [ 31  65  14]
#   [ 34  69  15]]
#
#  [[106 150  65]
#   [100 143  61]
#   [ 94 138  59]
#   ...
#   [ 30  64  13]
#   [ 32  67  13]
#   [ 34  69  15]]
#
#  [[111 161  72]
#   [103 153  66]
#   [ 97 149  64]
#   ...
#   [ 33  65  15]
#   [ 34  67  14]
#   [ 35  68  13]]
#
#  ...
#
#  [[250 250 250]
#   [250 250 250]
#   [251 251 251]
#   ...
#   [ 13  26   8]
#   [ 14  25   9]
#   [ 12  23   9]]
#
#  [[248 248 248]
#   [249 249 249]
#   [250 250 250]
#   ...
#   [ 14  29  10]
#   [ 15  28  10]
#   [ 14  27  10]]
#
#  [[250 250 250]
#   [251 251 251]
#   [249 249 249]
#   ...
#   [ 16  31  10]
#   [ 16  31  12]
#   [ 16  29  11]]]
